# %% [markdown]
# ## this is data from 20190122
# ## Sampled in Printer Lab

# %%
# %matplotlib inline
# %config InlineBackend.figure_format='svg'

import numpy as np
import pandas as pd
from datetime import datetime as dt
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib.ticker as mticker
sns.set()
from datetime import datetime, timedelta


import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
from statsmodels.sandbox.regression.predstd import wls_prediction_std

from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge
from scipy.stats import spearmanr, pearsonr
from sklearn.svm import SVR
from math import sqrt
from scipy.signal import savgol_filter

# %%
url="https://raw.githubusercontent.com/goudrevv/3D-Print-Lab/master/data/20190121.TXT"
data=pd.read_csv(url)
data.columns = ["time","temp","RH","0.3um","0.5um","1.0um","2.5um","5.0um","10um","pm1.0","pm2.5","pm10"]
data['time'] = pd.to_datetime(data['time'],unit='s')

# %%
data.describe()
# Out:
#                 temp             RH          0.3um          0.5um  \
# count  510674.000000  510674.000000  510674.000000  510674.000000
# mean       26.915971      -1.308783     298.251593      88.122544
# std         0.378316       0.813866     118.584594      35.193931
# min        20.450000      -2.070000       0.000000       0.000000
# 25%        26.910000      -1.660000     210.000000      62.000000
# 50%        26.990000      -1.530000     264.000000      78.000000
# 75%        27.070000      -1.370000     372.000000     110.000000
# max        27.260000      18.680000     978.000000     288.000000
#
#                1.0um          2.5um          5.0um           10um  \
# count  510674.000000  510674.000000  510674.000000  510674.000000
# mean       16.113826       1.528858       0.294983       0.106667
# std         8.189268       1.845520       0.771374       0.459768
# min         0.000000       0.000000       0.000000       0.000000
# 25%        10.000000       0.000000       0.000000       0.000000
# 50%        14.000000       2.000000       0.000000       0.000000
# 75%        20.000000       2.000000       0.000000       0.000000
# max        66.000000      16.000000       6.000000       4.000000
#
#                pm1.0         pm2.5           pm10
# count  510674.000000  510674.00000  510674.000000
# mean        0.699241       1.61563       1.854496
# std         0.782780       1.19225       1.365822
# min         0.000000       0.00000       0.000000
# 25%         0.000000       1.00000       1.000000
# 50%         1.000000       1.00000       2.000000
# 75%         1.000000       2.00000       3.000000
# max         5.000000       9.00000      10.000000

# %%
fig, ax1 = plt.subplots()
fig.set_size_inches(11.7, 8.27)


ax1.plot(data['time'],data['temp'],label='$degree (C)$',marker='o',linewidth=0.5,markersize=3,color='k')


plt.xticks(size = 15)
plt.yticks(size = 15)

ax1.set_xlabel('$Time$ $Line$',fontsize=16,color='k',labelpad=13)
ax1.grid(False)

ax1.legend(loc='best',fontsize=17,markerscale=4)

for label in ax1.xaxis.get_ticklabels():
       label.set_rotation(0)
ax1.xaxis.set_major_locator(mticker.MaxNLocator(7))
ax1.set_ylabel('$Temp$',color='k',fontsize=16,labelpad=13)
fig.savefig( 'temp.png' )
