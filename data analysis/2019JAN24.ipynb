# %% [markdown]
# ## Data collected from 19JAN23/24
# ## Nylon Testing

# %%
# %matplotlib inline
# %config InlineBackend.figure_format='svg'

import numpy as np
import pandas as pd
from datetime import datetime as dt
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib.ticker as mticker
sns.set()
from datetime import datetime, timedelta
from math import sqrt
from scipy.signal import savgol_filter

# %%
url="https://raw.githubusercontent.com/goudrevv/3D-Print-Lab/master/data/20190124.TXT"
data=pd.read_csv(url)
data.columns = ["time","temp","RH","0.3um","0.5um","1.0um","2.5um","5.0um","10um","pm1.0","pm2.5","pm10"]
data['time'] = pd.to_datetime(data['time'],unit='s')

# %%
data.describe()
# Out:
#                 temp             RH          0.3um          0.5um  \
# count  536869.000000  536869.000000  536869.000000  536869.000000
# mean       33.166993      16.258912     279.430748      78.851042
# std         4.141587       5.488376     223.614475      60.925123
# min        23.940000       3.660000       0.000000       0.000000
# 25%        31.000000      12.310000     108.000000      30.000000
# 50%        31.100000      19.400000     204.000000      58.000000
# 75%        33.460000      20.450000     432.000000     124.000000
# max        45.790000      22.210000    1536.000000     408.000000
#
#                1.0um          2.5um          5.0um           10um  \
# count  536869.000000  536869.000000  536869.000000  536869.000000
# mean        8.713895       0.585975       0.116934       0.049133
# std         7.518217       1.204678       0.499639       0.320827
# min         0.000000       0.000000       0.000000       0.000000
# 25%         2.000000       0.000000       0.000000       0.000000
# 50%         6.000000       0.000000       0.000000       0.000000
# 75%        14.000000       0.000000       0.000000       0.000000
# max        48.000000      12.000000       6.000000       4.000000
#
#                pm1.0          pm2.5           pm10
# count  536869.000000  536869.000000  536869.000000
# mean        0.602069       0.994976       1.086300
# std         0.932222       1.292646       1.410872
# min         0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000
# 75%         1.000000       2.000000       2.000000
# max         6.000000       7.000000       9.000000

# %%
fig, ax1 = plt.subplots()

fig.set_size_inches(11.7, 8.27)


ax1.plot(data['time'],data['temp'], 'k-', lw=3,label='temp')


plt.xticks(size = 15)
plt.yticks(size = 15)

plt.title('$Temperature$ $Data$',fontsize=20)
ax1.set_xlabel('$Time$ $Line$',fontsize=16,color='k',labelpad=13)
ax1.grid(False)

ax1.legend(loc='best',fontsize=17,markerscale=4)

for label in ax1.xaxis.get_ticklabels():
       label.set_rotation(0)
ax1.xaxis.set_major_locator(mticker.MaxNLocator(7))
ax1.set_ylabel('$Temperature$ $Degrees$ $C$',color='k',fontsize=16,labelpad=13)
#fig.savefig( 'temp_2019temp.png' )
# Out:
# Text(0, 0.5, '$Temperature$ $Degrees$ $C$')

# %%
fig, ax1 = plt.subplots()

fig.set_size_inches(11.7, 8.27)


ax1.plot(data['time'],data['0.3um'], 'k-', lw=3,label='0.3um')

plt.xticks(size = 15)
plt.yticks(size = 15)

plt.title('$Particle$ $Size$ $0.3um$',fontsize=20)
ax1.set_xlabel('$Time$ $Hours$',fontsize=16,color='k',labelpad=13)
ax1.grid(False)

ax1.legend(loc='best',fontsize=17,markerscale=4)

for label in ax1.xaxis.get_ticklabels():
       label.set_rotation(0)
ax1.xaxis.set_major_locator(mticker.MaxNLocator(7))
ax1.set_ylabel('$paritcle$ $number$ /0.1L$',color='k',fontsize=16,labelpad=13)
#fig.savefig( 'particle_size_0.3.png' )
# Out:
# Text(0, 0.5, '$paritcle$ $number$ /0.1L$')

# %%
fig, ax1 = plt.subplots()

fig.set_size_inches(11.7, 8.27)


ax1.plot(data['time'],data['0.5um'], 'k-', lw=3,label='0.5um')


plt.xticks(size = 15)
plt.yticks(size = 15)

plt.title('$Particle$ $Size$ $0.5um$',fontsize=20)
ax1.set_xlabel('$Time$ $Hours$',fontsize=16,color='k',labelpad=13)
ax1.grid(False)

ax1.legend(loc='best',fontsize=17,markerscale=4)

for label in ax1.xaxis.get_ticklabels():
       label.set_rotation(0)
ax1.xaxis.set_major_locator(mticker.MaxNLocator(7))
ax1.set_ylabel('$paritcle$ $number$ /0.1L$',color='k',fontsize=16,labelpad=13)
#fig.savefig( 'particle_size_0.5.png' )
# Out:
# Text(0, 0.5, '$paritcle$ $number$ /0.1L$')

# %%
fig, ax1 = plt.subplots()

fig.set_size_inches(11.7, 8.27)


ax1.plot(data['time'],data['1.0um'], 'k-', lw=3,label='1.0um')


plt.xticks(size = 15)
plt.yticks(size = 15)

plt.title('$Particle$ $Size$ $1um$',fontsize=20)
ax1.set_xlabel('$Time$ $Hours$',fontsize=16,color='k',labelpad=13)
ax1.grid(False)

ax1.legend(loc='best',fontsize=17,markerscale=4)

for label in ax1.xaxis.get_ticklabels():
       label.set_rotation(0)
ax1.xaxis.set_major_locator(mticker.MaxNLocator(7))
ax1.set_ylabel('Paritcle Number / 0.1L',color='k',fontsize=16,labelpad=13)
#fig.savefig( 'particle_size_1.png' )
# Out:
# Text(0, 0.5, 'Paritcle Number / 0.1L')

# %%
fig, ax1 = plt.subplots()

fig.set_size_inches(11.7, 8.27)


ax1.plot(data['time'],data['2.5um'], 'k-', lw=3,label='2.5um')


plt.xticks(size = 15)
plt.yticks(size = 15)

plt.title('$Particle$ $Size$ $2.5um$',fontsize=20)
ax1.set_xlabel('$Time$ $Hours$',fontsize=16,color='k',labelpad=13)
ax1.grid(False)

ax1.legend(loc='best',fontsize=17,markerscale=4)

for label in ax1.xaxis.get_ticklabels():
       label.set_rotation(0)
ax1.xaxis.set_major_locator(mticker.MaxNLocator(7))
ax1.set_ylabel('Paritcle Number / 0.1L',color='k',fontsize=16,labelpad=13)
#fig.savefig( 'particle_size_2.5.png' )
# Out:
# Text(0, 0.5, 'Paritcle Number / 0.1L')

# %%
fig, ax1 = plt.subplots()

fig.set_size_inches(11.7, 8.27)


ax1.plot(data['time'],data['5.0um'], 'k-', lw=3,label='5.0um')


plt.xticks(size = 15)
plt.yticks(size = 15)

plt.title('$Particle$ $Size$ $5um$',fontsize=20)
ax1.set_xlabel('$Time$ $Hours$',fontsize=16,color='k',labelpad=13)
ax1.grid(False)

ax1.legend(loc='best',fontsize=17,markerscale=4)

for label in ax1.xaxis.get_ticklabels():
       label.set_rotation(0)
ax1.xaxis.set_major_locator(mticker.MaxNLocator(7))
ax1.set_ylabel('Paritcle Number / 0.1L',color='k',fontsize=16,labelpad=13)
#fig.savefig( 'particle_size_5.png' )
# Out:
# Text(0, 0.5, 'Paritcle Number / 0.1L')

# %%
fig, ax1 = plt.subplots()

fig.set_size_inches(11.7, 8.27)


ax1.plot(data['time'],data['10um'], 'k-', lw=3,label='10.0um')


plt.xticks(size = 15)
plt.yticks(size = 15)

plt.title('$Particle$ $Size$ $10um$',fontsize=20)
ax1.set_xlabel('$Time$ $Hours$',fontsize=16,color='k',labelpad=13)
ax1.grid(False)

ax1.legend(loc='best',fontsize=17,markerscale=4)

for label in ax1.xaxis.get_ticklabels():
       label.set_rotation(0)
ax1.xaxis.set_major_locator(mticker.MaxNLocator(7))
ax1.set_ylabel('Particle Number / 0.1L',color='k',fontsize=16,labelpad=13)
#fig.savefig( 'particle_size_10.png' )
# Out:
# Text(0, 0.5, 'Particle Number / 0.1L')
